# %%
import pandas as pd
import numpy as  np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
anime=pd.read_csv("anime.csv")

# %%
rating=pd.read_csv("rating.csv")

# %%
anime
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 2      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 3                                       Sci-Fi, Thriller     TV       24
# 4      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# ...                                                  ...    ...      ...
# 12289                                             Hentai    OVA        1
# 12290                                             Hentai    OVA        1
# 12291                                             Hentai    OVA        4
# 12292                                             Hentai    OVA        1
# 12293                                             Hentai  Movie        1
#
#        rating  members
# 0        9.37   200630
# 1        9.26   793665
# 2        9.25   114262
# 3        9.17   673572
# 4        9.16   151266
# ...       ...      ...
# 12289    4.15      211
# 12290    4.28      183
# 12291    4.88      219
# 12292    4.98      175
# 12293    5.46      142
#
# [12294 rows x 7 columns]

# %%
rating
# Out:
#          user_id  anime_id  rating
# 0              1        20      -1
# 1              1        24      -1
# 2              1        79      -1
# 3              1       226      -1
# 4              1       241      -1
# ...          ...       ...     ...
# 7813732    73515     16512       7
# 7813733    73515     17187       9
# 7813734    73515     22145      10
# 7813735    73516       790       9
# 7813736    73516      8074       9
#
# [7813737 rows x 3 columns]

# %%
anime.shape
# Out:
# (12294, 7)

# %%
rating.shape
# Out:
# (7813737, 3)

# %%
anime.describe()
# Out:
#            anime_id        rating       members
# count  12294.000000  12064.000000  1.229400e+04
# mean   14058.221653      6.473902  1.807134e+04
# std    11455.294701      1.026746  5.482068e+04
# min        1.000000      1.670000  5.000000e+00
# 25%     3484.250000      5.880000  2.250000e+02
# 50%    10260.500000      6.570000  1.550000e+03
# 75%    24794.500000      7.180000  9.437000e+03
# max    34527.000000     10.000000  1.013917e+06

# %%
rating.describe()
# Out:
#             user_id      anime_id        rating
# count  7.813737e+06  7.813737e+06  7.813737e+06
# mean   3.672796e+04  8.909072e+03  6.144030e+00
# std    2.099795e+04  8.883950e+03  3.727800e+00
# min    1.000000e+00  1.000000e+00 -1.000000e+00
# 25%    1.897400e+04  1.240000e+03  6.000000e+00
# 50%    3.679100e+04  6.213000e+03  7.000000e+00
# 75%    5.475700e+04  1.409300e+04  9.000000e+00
# max    7.351600e+04  3.451900e+04  1.000000e+01

# %%
anime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12294 entries, 0 to 12293
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   anime_id  12294 non-null  int64
#  1   name      12294 non-null  object
#  2   genre     12232 non-null  object
#  3   type      12269 non-null  object
#  4   episodes  12294 non-null  object
#  5   rating    12064 non-null  float64
#  6   members   12294 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 672.5+ KB

# %%
rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7813737 entries, 0 to 7813736
# Data columns (total 3 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   user_id   int64
#  1   anime_id  int64
#  2   rating    int64
# dtypes: int64(3)
# memory usage: 178.8 MB

# %%
anime.isna().any()
# Out:
# anime_id    False
# name        False
# genre        True
# type         True
# episodes    False
# rating       True
# members     False
# dtype: bool

# %%
rating.isna().any()
# Out:
# user_id     False
# anime_id    False
# rating      False
# dtype: bool

# %%
anime.isna().sum()
# Out:
# anime_id      0
# name          0
# genre        62
# type         25
# episodes      0
# rating      230
# members       0
# dtype: int64

# %%
rating.isna().sum()
# Out:
# user_id     0
# anime_id    0
# rating      0
# dtype: int64

# %%
anime['rating'].fillna(anime['rating'].mean(),inplace=True)
anime['genre'].fillna(anime['genre'].mode()[0],inplace=True)
anime['type'].fillna(anime['type'].mode()[0],inplace=True)

# %%
anime.isna().sum()
# Out:
# anime_id    0
# name        0
# genre       0
# type        0
# episodes    0
# rating      0
# members     0
# dtype: int64

# %%
rating.isna().sum()
# Out:
# user_id     0
# anime_id    0
# rating      0
# dtype: int64

# %%
sns.displot(x='rating',data=anime,kde=True)
plt.xlabel('Rating')
plt.ylabel('Count')
# Out:
# C:\Users\vivek\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(4.944444444444445, 0.5, 'Count')

# %%
anime[anime.duplicated()].shape[0]
# Out:
# 0

# %%
rating[rating.duplicated()].shape[0]
# Out:
# 1

# %%
rating.drop_duplicates(keep='first',inplace=True)
rating[rating.duplicated()].shape[0]
# Out:
# 0

# %%
anime
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 2      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 3                                       Sci-Fi, Thriller     TV       24
# 4      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# ...                                                  ...    ...      ...
# 12289                                             Hentai    OVA        1
# 12290                                             Hentai    OVA        1
# 12291                                             Hentai    OVA        4
# 12292                                             Hentai    OVA        1
# 12293                                             Hentai  Movie        1
#
#        rating  members
# 0        9.37   200630
# 1        9.26   793665
# 2        9.25   114262
# 3        9.17   673572
# 4        9.16   151266
# ...       ...      ...
# 12289    4.15      211
# 12290    4.28      183
# 12291    4.88      219
# 12292    4.98      175
# 12293    5.46      142
#
# [12294 rows x 7 columns]

# %%
rating
# Out:
#          user_id  anime_id  rating
# 0              1        20      -1
# 1              1        24      -1
# 2              1        79      -1
# 3              1       226      -1
# 4              1       241      -1
# ...          ...       ...     ...
# 7813732    73515     16512       7
# 7813733    73515     17187       9
# 7813734    73515     22145      10
# 7813735    73516       790       9
# 7813736    73516      8074       9
#
# [7813736 rows x 3 columns]

# %%
anime.name.value_counts()
# Out:
# name
# Shi Wan Ge Leng Xiaohua                           2
# Saru Kani Gassen                                  2
# Bakabon Osomatsu no Karee wo Tazunete Sansenri    1
# Backkom Meogeujan Yeohaeng                        1
# Backkom Mission Impossible                        1
#                                                  ..
# Yoroiden Samurai Troopers Kikoutei Densetsu       1
# Yuu☆Yuu☆Hakusho: Mu Mu Hakusho                    1
# 3-gatsu no Lion meets Bump of Chicken             1
# Bannou Bunka Neko-Musume                          1
# Yasuji no Pornorama: Yacchimae!!                  1
# Name: count, Length: 12292, dtype: int64

# %%
anime.type.value_counts()
# Out:
# type
# TV         3812
# OVA        3311
# Movie      2348
# Special    1676
# ONA         659
# Music       488
# Name: count, dtype: int64

# %%
anime.columns
# Out:
# Index(['anime_id', 'name', 'genre', 'type', 'episodes', 'rating', 'members'], dtype='object')

# %%
anime.genre.value_counts()
# Out:
# genre
# Hentai                                                  885
# Comedy                                                  523
# Music                                                   301
# Kids                                                    199
# Comedy, Slice of Life                                   179
#                                                        ...
# Adventure, Drama, Fantasy, Game, Sci-Fi                   1
# Adventure, Demons, Fantasy, Historical                    1
# Action, Comedy, Drama, Mecha, Music, Sci-Fi, Shounen      1
# Action, Comedy, Fantasy, Mecha, Sci-Fi, Shounen           1
# Hentai, Slice of Life                                     1
# Name: count, Length: 3264, dtype: int64

# %%
rating.columns
# Out:
# Index(['user_id', 'anime_id', 'rating'], dtype='object')

# %%
anime
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 2      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 3                                       Sci-Fi, Thriller     TV       24
# 4      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# ...                                                  ...    ...      ...
# 12289                                             Hentai    OVA        1
# 12290                                             Hentai    OVA        1
# 12291                                             Hentai    OVA        4
# 12292                                             Hentai    OVA        1
# 12293                                             Hentai  Movie        1
#
#        rating  members
# 0        9.37   200630
# 1        9.26   793665
# 2        9.25   114262
# 3        9.17   673572
# 4        9.16   151266
# ...       ...      ...
# 12289    4.15      211
# 12290    4.28      183
# 12291    4.88      219
# 12292    4.98      175
# 12293    5.46      142
#
# [12294 rows x 7 columns]

# %%
rating
# Out:
#          user_id  anime_id  rating
# 0              1        20      -1
# 1              1        24      -1
# 2              1        79      -1
# 3              1       226      -1
# 4              1       241      -1
# ...          ...       ...     ...
# 7813732    73515     16512       7
# 7813733    73515     17187       9
# 7813734    73515     22145      10
# 7813735    73516       790       9
# 7813736    73516      8074       9
#
# [7813736 rows x 3 columns]

# %%
data=pd.merge(anime,rating,on='anime_id',suffixes=[None,'_user'])
data=data.rename(columns={'rating_user':'user_rating'})
data
# Out:
#          anime_id                                               name  \
# 0           32281                                     Kimi no Na wa.
# 1           32281                                     Kimi no Na wa.
# 2           32281                                     Kimi no Na wa.
# 3           32281                                     Kimi no Na wa.
# 4           32281                                     Kimi no Na wa.
# ...           ...                                                ...
# 7813721      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 7813722      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 7813723      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 7813724     26081                   Yasuji no Pornorama: Yacchimae!!
# 7813725     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                         genre   type episodes  rating  \
# 0        Drama, Romance, School, Supernatural  Movie        1    9.37
# 1        Drama, Romance, School, Supernatural  Movie        1    9.37
# 2        Drama, Romance, School, Supernatural  Movie        1    9.37
# 3        Drama, Romance, School, Supernatural  Movie        1    9.37
# 4        Drama, Romance, School, Supernatural  Movie        1    9.37
# ...                                       ...    ...      ...     ...
# 7813721                                Hentai    OVA        1    4.98
# 7813722                                Hentai    OVA        1    4.98
# 7813723                                Hentai    OVA        1    4.98
# 7813724                                Hentai  Movie        1    5.46
# 7813725                                Hentai  Movie        1    5.46
#
#          members  user_id  user_rating
# 0         200630       99            5
# 1         200630      152           10
# 2         200630      244           10
# 3         200630      271           10
# 4         200630      278           -1
# ...          ...      ...          ...
# 7813721      175    39532           -1
# 7813722      175    48766           -1
# 7813723      175    60365            4
# 7813724      142    27364           -1
# 7813725      142    48766           -1
#
# [7813726 rows x 9 columns]

# %%
top_anime=anime.sort_values(['members'],ascending=False)
plt.figure(figsize=(20,20))
sns.barplot(x=top_anime['name'][:20],y=top_anime['members'][:20])
# Out:
# <Axes: xlabel='name', ylabel='members'>

# %%
top_anime['name'][:20]
# Out:
# 40                             Death Note
# 86                     Shingeki no Kyojin
# 804                      Sword Art Online
# 1        Fullmetal Alchemist: Brotherhood
# 159                          Angel Beats!
# 19        Code Geass: Hangyaku no Lelouch
# 841                                Naruto
# 3                             Steins;Gate
# 445                      Mirai Nikki (TV)
# 131                             Toradora!
# 582                                Bleach
# 760                            Elfen Lied
# 449                           Tokyo Ghoul
# 118                       No Game No Life
# 200                   Fullmetal Alchemist
# 288                            Fairy Tail
# 643                        Ao no Exorcist
# 440                            Soul Eater
# 13     Code Geass: Hangyaku no Lelouch R2
# 223                               Clannad
# Name: name, dtype: object

# %%
plt.figure(figsize=(20,20))
sns.barplot(x=top_anime['name'][:20],y=top_anime['rating'][:20])
# Out:
# <Axes: xlabel='name', ylabel='rating'>

# %%
anime
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 2      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 3                                       Sci-Fi, Thriller     TV       24
# 4      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# ...                                                  ...    ...      ...
# 12289                                             Hentai    OVA        1
# 12290                                             Hentai    OVA        1
# 12291                                             Hentai    OVA        4
# 12292                                             Hentai    OVA        1
# 12293                                             Hentai  Movie        1
#
#        rating  members
# 0        9.37   200630
# 1        9.26   793665
# 2        9.25   114262
# 3        9.17   673572
# 4        9.16   151266
# ...       ...      ...
# 12289    4.15      211
# 12290    4.28      183
# 12291    4.88      219
# 12292    4.98      175
# 12293    5.46      142
#
# [12294 rows x 7 columns]

# %%
anime['type'].value_counts()
# Out:
# type
# TV         3812
# OVA        3311
# Movie      2348
# Special    1676
# ONA         659
# Music       488
# Name: count, dtype: int64

# %%
from wordcloud import WordCloud
wordcloud=WordCloud(width=1000,height=400,max_font_size=100).generate(anime['genre'].str.cat(sep=",|,|,"))
plt.imshow(wordcloud)

# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\vivek\anaconda3\lib\site-packages (1.9.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.6.1 in c:\users\vivek\anaconda3\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\users\vivek\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\vivek\anaconda3\lib\site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vivek\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\vivek\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vivek\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\vivek\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\vivek\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\vivek\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vivek\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\vivek\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
data['user_rating'].replace(to_replace=-1,value=np.nan,inplace=True)
data=data.dropna(axis=0)
data
# Out:
#          anime_id                                               name  \
# 0           32281                                     Kimi no Na wa.
# 1           32281                                     Kimi no Na wa.
# 2           32281                                     Kimi no Na wa.
# 3           32281                                     Kimi no Na wa.
# 5           32281                                     Kimi no Na wa.
# ...           ...                                                ...
# 7813712      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 7813715      5543                                        Under World
# 7813716      5543                                        Under World
# 7813719      5621                     Violence Gekiga David no Hoshi
# 7813723      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
#
#                                         genre   type episodes  rating  \
# 0        Drama, Romance, School, Supernatural  Movie        1    9.37
# 1        Drama, Romance, School, Supernatural  Movie        1    9.37
# 2        Drama, Romance, School, Supernatural  Movie        1    9.37
# 3        Drama, Romance, School, Supernatural  Movie        1    9.37
# 5        Drama, Romance, School, Supernatural  Movie        1    9.37
# ...                                       ...    ...      ...     ...
# 7813712                                Hentai    OVA        1    4.15
# 7813715                                Hentai    OVA        1    4.28
# 7813716                                Hentai    OVA        1    4.28
# 7813719                                Hentai    OVA        4    4.88
# 7813723                                Hentai    OVA        1    4.98
#
#          members  user_id  user_rating
# 0         200630       99          5.0
# 1         200630      152         10.0
# 2         200630      244         10.0
# 3         200630      271         10.0
# 5         200630      322         10.0
# ...          ...      ...          ...
# 7813712      211    58483          1.0
# 7813715      183    49503          4.0
# 7813716      183    58483          1.0
# 7813719      219    49503          6.0
# 7813723      175    60365          4.0
#
# [6337238 rows x 9 columns]

# %%
no_of_reviews=data.groupby('anime_id').size().reset_index()
no_of_reviews.columns=['anime_id','review_count']
data=data.merge(no_of_reviews,on='anime_id')
data
# Out:
#          anime_id                                               name  \
# 0           32281                                     Kimi no Na wa.
# 1           32281                                     Kimi no Na wa.
# 2           32281                                     Kimi no Na wa.
# 3           32281                                     Kimi no Na wa.
# 4           32281                                     Kimi no Na wa.
# ...           ...                                                ...
# 6337233      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 6337234      5543                                        Under World
# 6337235      5543                                        Under World
# 6337236      5621                     Violence Gekiga David no Hoshi
# 6337237      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
#
#                                         genre   type episodes  rating  \
# 0        Drama, Romance, School, Supernatural  Movie        1    9.37
# 1        Drama, Romance, School, Supernatural  Movie        1    9.37
# 2        Drama, Romance, School, Supernatural  Movie        1    9.37
# 3        Drama, Romance, School, Supernatural  Movie        1    9.37
# 4        Drama, Romance, School, Supernatural  Movie        1    9.37
# ...                                       ...    ...      ...     ...
# 6337233                                Hentai    OVA        1    4.15
# 6337234                                Hentai    OVA        1    4.28
# 6337235                                Hentai    OVA        1    4.28
# 6337236                                Hentai    OVA        4    4.88
# 6337237                                Hentai    OVA        1    4.98
#
#          members  user_id  user_rating  review_count
# 0         200630       99          5.0          1961
# 1         200630      152         10.0          1961
# 2         200630      244         10.0          1961
# 3         200630      271         10.0          1961
# 4         200630      322         10.0          1961
# ...          ...      ...          ...           ...
# 6337233      211    58483          1.0             2
# 6337234      183    49503          4.0             2
# 6337235      183    58483          1.0             2
# 6337236      219    49503          6.0             1
# 6337237      175    60365          4.0             1
#
# [6337238 rows x 10 columns]

# %%
animemat = data.pivot_table(index='user_id',columns='name',values='user_rating')
animemat.head()
# Out:
# name     &quot;0&quot;  \
# user_id
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 5                  NaN
# 7                  NaN
#
# name     &quot;Aesop&quot; no Ohanashi yori: Ushi to Kaeru, Yokubatta Inu  \
# user_id
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 5                                                      NaN
# 7                                                      NaN
#
# name     &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hatsukoi  \
# user_id
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 5                                                      NaN
# 7                                                      NaN
#
# name     &quot;Bungaku Shoujo&quot; Memoire  &quot;Bungaku Shoujo&quot; Movie  \
# user_id
# 1                                       NaN                               NaN
# 2                                       NaN                               NaN
# 3                                       NaN                               NaN
# 5                                       NaN                               NaN
# 7                                       NaN                               NaN
#
# name     &quot;Eiji&quot;  .hack//G.U. Returner  .hack//G.U. Trilogy  \
# user_id
# 1                     NaN                   NaN                  NaN
# 2                     NaN                   NaN                  NaN
# 3                     NaN                   NaN                  NaN
# 5                     NaN                   NaN                  NaN
# 7                     NaN                   NaN                  NaN
#
# name     .hack//G.U. Trilogy: Parody Mode  .hack//Gift  ...  \
# user_id                                                 ...
# 1                                     NaN          NaN  ...
# 2                                     NaN          NaN  ...
# 3                                     NaN          NaN  ...
# 5                                     NaN          NaN  ...
# 7                                     NaN          NaN  ...
#
# name     lilac (bombs Jun Togawa)  makemagic  s.CRY.ed  vivi  xxxHOLiC  \
# user_id
# 1                             NaN        NaN       NaN   NaN       NaN
# 2                             NaN        NaN       NaN   NaN       NaN
# 3                             NaN        NaN       NaN   NaN       NaN
# 5                             NaN        NaN       NaN   NaN       2.0
# 7                             NaN        NaN       NaN   NaN       NaN
#
# name     xxxHOLiC Kei  xxxHOLiC Movie: Manatsu no Yoru no Yume  xxxHOLiC Rou  \
# user_id
# 1                 NaN                                      NaN           NaN
# 2                 NaN                                      NaN           NaN
# 3                 NaN                                      NaN           NaN
# 5                 NaN                                      NaN           NaN
# 7                 NaN                                      NaN           NaN
#
# name     xxxHOLiC Shunmuki   ◯
# user_id
# 1                      NaN NaN
# 2                      NaN NaN
# 3                      NaN NaN
# 5                      NaN NaN
# 7                      NaN NaN
#
# [5 rows x 9926 columns]

# %%
weighted_data=data.groupby('anime_id')[['name','rating','review_count','members']].max().reset_index()
weighted_data
# Out:
#       anime_id                               name  rating  review_count  \
# 0            1                       Cowboy Bebop    8.82         13449
# 1            5    Cowboy Bebop: Tengoku no Tobira    8.40          5790
# 2            6                             Trigun    8.32          9385
# 3            7                 Witch Hunter Robin    7.36          2169
# 4            8             Beet the Vandel Buster    7.06           308
# ...        ...                                ...     ...           ...
# 9921     34324                       Chiryokumaru    5.40            11
# 9922     34325          Pokemon XY&amp;Z Specials    7.05            15
# 9923     34349  Diamond no Ace: Second Season OVA    7.25             3
# 9924     34367                  Long Riders Recap    5.97             4
# 9925     34475   Monster Strike: Rain of Memories    6.58             3
#
#       members
# 0      486824
# 1      137636
# 2      283069
# 3       64905
# 4        9848
# ...       ...
# 9921      817
# 9922     1454
# 9923     1885
# 9924      582
# 9925      313
#
# [9926 rows x 5 columns]

# %%
weighted_data.sort_values('review_count',ascending=False)[['anime_id','name','review_count']].head()
# Out:
#       anime_id                             name  review_count
# 1388      1535                       Death Note         34226
# 6323     11757                 Sword Art Online         26310
# 7059     16498               Shingeki no Kyojin         25289
# 1426      1575  Code Geass: Hangyaku no Lelouch         24126
# 4567      6547                     Angel Beats!         23565

# %%
deathnote_user_ratings=animemat['Death Note']

# %%
similar_to_deathnote=animemat.corrwith(deathnote_user_ratings)
# Out:
# C:\Users\vivek\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2846: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\vivek\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2705: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)

# %%
corr_deathnote=pd.DataFrame(similar_to_deathnote,columns=['Correlation']).reset_index()

# %%
corr_deathnote.dropna(inplace=True)

# %%
corr_deathnote.head()
# Out:
#                                                 name  Correlation
# 0                                      &quot;0&quot;     0.133440
# 2  &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hat...     0.104206
# 3                 &quot;Bungaku Shoujo&quot; Memoire     0.089254
# 4                   &quot;Bungaku Shoujo&quot; Movie     0.196000
# 5                                   &quot;Eiji&quot;     0.490290

# %%
corr_deathnote=corr_deathnote.merge(weighted_data[['review_count','name']],on='name')

# %%
corr_deathnote
# Out:
#                                                    name  Correlation  \
# 0                                         &quot;0&quot;     0.133440
# 1     &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hat...     0.104206
# 2                    &quot;Bungaku Shoujo&quot; Memoire     0.089254
# 3                      &quot;Bungaku Shoujo&quot; Movie     0.196000
# 4                                      &quot;Eiji&quot;     0.490290
# ...                                                 ...          ...
# 8591                                       xxxHOLiC Kei     0.212093
# 8592            xxxHOLiC Movie: Manatsu no Yoru no Yume     0.142862
# 8593                                       xxxHOLiC Rou     0.179616
# 8594                                  xxxHOLiC Shunmuki     0.134981
# 8595                                                  ◯     0.463713
#
#       review_count
# 0               17
# 1              635
# 2              662
# 3             1295
# 4               14
# ...            ...
# 8591          2796
# 8592          1889
# 8593          1190
# 8594          1534
# 8595             6
#
# [8596 rows x 3 columns]

# %%
h=corr_deathnote[corr_deathnote['review_count']>100].sort_values('Correlation',ascending=False).head()

# %%
h.sort_values('review_count',ascending=False).head(5)
# Out:
#                            name  Correlation  review_count
# 1493                 Death Note     1.000000         34226
# 1494         Death Note Rewrite     0.485444          3006
# 1413  Daiakuji: The Xena Buster     0.447568           145
# 2272               Gallery Fake     0.443418           135
# 1650        Discode: Ijou Seiai     0.449202           113

# %%
h
# Out:
#                            name  Correlation  review_count
# 1493                 Death Note     1.000000         34226
# 1494         Death Note Rewrite     0.485444          3006
# 1650        Discode: Ijou Seiai     0.449202           113
# 1413  Daiakuji: The Xena Buster     0.447568           145
# 2272               Gallery Fake     0.443418           135
